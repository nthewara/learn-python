# %%
get-date
# Out:
# Saturday, 27 June 2020 6:35:13 PM

# %%
Import-Module -Name Az

# %%
get-command
# Out:
# CommandType     Name                                               Version    Source
# -----------     ----                                               -------    ------
# Alias           Add-AdlAnalyticsDataSource                         1.0.2      Az.DataLakeAnalytics
# Alias           Add-AdlAnalyticsFirewallRule                       1.0.2      Az.DataLakeAnalytics
# Alias           Add-AdlStoreFirewallRule                           1.2.8      Az.DataLakeStore
# Alias           Add-AdlStoreItemContent                            1.2.8      Az.DataLakeStore
# Alias           Add-AdlStoreTrustedIdProvider                      1.2.8      Az.DataLakeStore
# Alias           Add-AdlStoreVirtualNetworkRule                     1.2.8      Az.DataLakeStore
# Alias           Add-AppPackage                                     2.0.1.0    Appx
# Alias           Add-AppPackageVolume                               2.0.1.0    Appx
# ...

# %%
jupyter kernelspec list
# Out:
# Available kernels:
#   .net-csharp        C:\Users\nirmal\AppData\Roaming\jupyter\kernels\.net-csharp
#   .net-fsharp        C:\Users\nirmal\AppData\Roaming\jupyter\kernels\.net-fsharp
#   .net-powershell    C:\Users\nirmal\AppData\Roaming\jupyter\kernels\.net-powershell
#   python3            c:\python38\share\jupyter\kernels\python3

# %%
1+1
# Out:
# 2
